# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'short_exp_v1.4_0yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
for filtername in 'ugrizy':

    metric = metrics.CountMetric(col='observationStartMJD')
    slicer = slicers.HealpixSlicer()
    sql = 'filter="%s" and note="short"' % filtername

    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql))
    sql = 'filter="%s" and note!="short" and note!=""' % filtername
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()
bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint filter="z" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 2006 visits
# Running:  ['opsim_Count_observationStartMJD_z_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 300 visits
# Running:  ['opsim_Count_observationStartMJD_g_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 1129 visits
# Running:  ['opsim_Count_observationStartMJD_z_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 2097 visits
# Running:  ['opsim_Count_observationStartMJD_y_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Querying database SummaryAllProps with constraint filter="i" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 1265 visits
# Running:  ['opsim_Count_observationStartMJD_i_and_note!short_and_note!_HEAL']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:298: UserWarning: No data matching constraint filter="u" and note="short"
#   warnings.warn('No data matching constraint %s' % constraint)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:302: UserWarning:  This means skipping metrics ['Count observationStartMJD : u and noteshort : HealpixSlicer']
#   warnings.warn(' This means skipping metrics %s' % metricsSkipped)
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 180 visits
# Running:  ['opsim_Count_observationStartMJD_g_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 903 visits
# Running:  ['opsim_Count_observationStartMJD_i_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and note="short" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 354 visits
# Running:  ['opsim_Count_observationStartMJD_r_and_noteshort_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 3540 visits
# Running:  ['opsim_Count_observationStartMJD_y_and_note!short_and_note!_HEAL']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:495: RuntimeWarning: invalid value encountered in equal
#   b.metricValues.mask = np.where(b.metricValues.data == b.metric.badval,
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 676 visits
# Running:  ['opsim_Count_observationStartMJD_r_and_note!short_and_note!_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and note!="short" and note!="" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Plotting figures with "filter="z" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:298: UserWarning: No data matching constraint filter="u" and note!="short" and note!=""
#   warnings.warn('No data matching constraint %s' % constraint)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:302: UserWarning:  This means skipping metrics ['Count observationStartMJD : u and note!short and note! : HealpixSlicer']
#   warnings.warn(' This means skipping metrics %s' % metricsSkipped)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 687 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 0.7992  dipole: lon: 7.95311, lat: -26.5837, amp: 2.54714
# Plotting complete.
# Plotting figures with "filter="g" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 266 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 9.65802  dipole: lon: 81.9396, lat: 22.8824, amp: 16.3618
# Plotting complete.
# Plotting figures with "filter="z" and note="short"" constraint now.
# monopole: -0.746667  dipole: lon: -25.1462, lat: -35.8323, amp: 3.29445
# Plotting complete.
# Plotting figures with "filter="y" and note="short"" constraint now.
# monopole: 1.94913  dipole: lon: 4.52602, lat: -51.5601, amp: 0.89612
# Plotting complete.
# Plotting figures with "filter="u" and note="short"" constraint now.
# Plotting complete.
# Plotting figures with "filter="i" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:538: UserWarning: MetricBundle (opsim_Count_observationStartMJD_u_and_noteshort_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 447 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 6.53337  dipole: lon: 115.656, lat: 18.8291, amp: 5.8613
# Plotting complete.
# Plotting figures with "filter="g" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 3.7016  dipole: lon: -175.514, lat: 28.1981, amp: 2.84954
# Plotting complete.
# Plotting figures with "filter="i" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: -0.793947  dipole: lon: -29.0346, lat: -40.2929, amp: 3.16405
# Plotting complete.
# Plotting figures with "filter="r" and note="short"" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 4.02403  dipole: lon: 176.948, lat: 33.439, amp: 2.94648
# Plotting complete.
# Plotting figures with "filter="y" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 600 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 0.543132  dipole: lon: 2.89232, lat: -31.6362, amp: 4.05019
# Plotting complete.
# Plotting figures with "filter="r" and note!="short" and note!=""" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 733 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 3.65518  dipole: lon: 61.898, lat: 25.7738, amp: 6.23459
# Plotting complete.
# Plotting figures with "filter="u" and note!="short" and note!=""" constraint now.
# Plotting complete.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:538: UserWarning: MetricBundle (opsim_Count_observationStartMJD_u_and_note!short_and_note!_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
