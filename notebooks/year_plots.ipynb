# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

# %%
dbFile = 'testrolling_v1.4_2yrs.db'
# This connection checks which version it thinks the database is and should do the right thing schema-wise
conn = db.OpsimDatabase(dbFile)
outDir='temp'
resultsDb = db.ResultsDb(outDir=outDir)

# %%
bundleList = []
sql = 'filter="r"'
sqls = [sql+' and night > %f and night < %f' % (night, night+365.25) for night in np.arange(0,365.25*4, 365.25)]
sqls2 = [sql+' and night > %f and night < %f' % (night, night+365.25) for night in np.arange(365.25/2,365.25/2+365.25*4, 365.25)]
sqls.extend(sqls2)
metric = metrics.CountMetric(col='fieldRA')
slicer = slicers.HealpixSlicer()
plotDict={'percentileClip': 95.}
for sql in sqls:
    
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes

# %%
bd = metricBundles.makeBundlesDictFromList(bundleList)
bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
bg.runAll()

bg.plotAll(closefigs=False)
# Out:
# Querying database SummaryAllProps with constraint filter="r" and night > 547.875000 and night < 913.125000 for columns ['fieldRA', 'fieldDec']
# Found 48454 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_547_875000_and_night_lt_913_125000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and night > 0.000000 and night < 365.250000 for columns ['fieldRA', 'fieldDec']
# Found 45954 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_0_000000_and_night_lt_365_250000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and night > 182.625000 and night < 547.875000 for columns ['fieldRA', 'fieldDec']
# Found 41025 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_182_625000_and_night_lt_547_875000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and night > 913.125000 and night < 1278.375000 for columns ['fieldRA', 'fieldDec']
# Found 3428 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_913_125000_and_night_lt_1278_375000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and night > 1278.375000 and night < 1643.625000 for columns ['fieldRA', 'fieldDec']
# Querying database SummaryAllProps with constraint filter="r" and night > 1095.750000 and night < 1461.000000 for columns ['fieldRA', 'fieldDec']
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:298: UserWarning: No data matching constraint filter="r" and night > 1278.375000 and night < 1643.625000
#   warnings.warn('No data matching constraint %s' % constraint)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:302: UserWarning:  This means skipping metrics ['Count fieldRA : r and night > 1278.375000 and night < 1643.625000 : HealpixSlicer']
#   warnings.warn(' This means skipping metrics %s' % metricsSkipped)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:298: UserWarning: No data matching constraint filter="r" and night > 1095.750000 and night < 1461.000000
#   warnings.warn('No data matching constraint %s' % constraint)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:302: UserWarning:  This means skipping metrics ['Count fieldRA : r and night > 1095.750000 and night < 1461.000000 : HealpixSlicer']
#   warnings.warn(' This means skipping metrics %s' % metricsSkipped)
# Querying database SummaryAllProps with constraint filter="r" and night > 730.500000 and night < 1095.750000 for columns ['fieldRA', 'fieldDec']
# Found 31475 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_730_500000_and_night_lt_1095_750000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and night > 365.250000 and night < 730.500000 for columns ['fieldRA', 'fieldDec']
# Found 41043 visits
# Running:  ['opsim_Count_fieldRA_r_and_night_gt_365_250000_and_night_lt_730_500000_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="r" and night > 547.875000 and night < 913.125000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 1296 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 12.6344  dipole: lon: 114.292, lat: -69.7672, amp: 13.768
# Plotting complete.
# Plotting figures with "filter="r" and night > 0.000000 and night < 365.250000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 2156 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 15.5346  dipole: lon: 102.428, lat: -41.2516, amp: 2.86385
# Plotting complete.
# Plotting figures with "filter="r" and night > 182.625000 and night < 547.875000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 1821 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 15.347  dipole: lon: 110.528, lat: 36.6966, amp: 5.36234
# Plotting complete.
# Plotting figures with "filter="r" and night > 913.125000 and night < 1278.375000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 397 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 2.55404  dipole: lon: -123.424, lat: -21.8104, amp: 2.06287
# Plotting complete.
# Plotting figures with "filter="r" and night > 1278.375000 and night < 1643.625000" constraint now.
# Plotting complete.
# Plotting figures with "filter="r" and night > 1095.750000 and night < 1461.000000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:538: UserWarning: MetricBundle (opsim_Count_fieldRA_r_and_night_gt_1278_375000_and_night_lt_1643_625000_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/plots/plotHandler.py:538: UserWarning: MetricBundle (opsim_Count_fieldRA_r_and_night_gt_1095_750000_and_night_lt_1461_000000_HEAL) has no attribute "metricValues". Either the values have not been calculated or they have been deleted.
#   warnings.warn(msg)
# Plotting complete.
# Plotting figures with "filter="r" and night > 730.500000 and night < 1095.750000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 1564 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 9.3506  dipole: lon: 140.431, lat: -50.3175, amp: 13.1132
# Plotting complete.
# Plotting figures with "filter="r" and night > 365.250000 and night < 730.500000" constraint now.
# /Users/yoachim/gitRepos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 1927 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 12.8877  dipole: lon: 105.659, lat: -37.2815, amp: 6.69143
# Plotting complete.
