# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles
import glob

# %%
files = glob.glob('*10yrs.db')
for dbFile in files:
    # This connection checks which version it thinks the database is and should do the right thing schema-wise
    conn = db.OpsimDatabase(dbFile)
    outDir='gs_' + dbFile[:-3]
    resultsDb = db.ResultsDb(outDir=outDir)

    bundleList = []
    plotDict = {}
    for filtername in 'ugrizy':
        sql = 'filter="%s"' % filtername
        metric = metrics.Coaddm5Metric()
        slicer = slicers.HealpixSlicer()
        #plotDict = {'colorMax': 27.4}
        bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))

        sql = 'filter="%s" and seeingFwhmEff <= 0.7 and sunAlt < -18' % filtername
        metric = metrics.Coaddm5Metric(metricName='gs_coaddM5')
        slicer = slicers.HealpixSlicer()
        #plotDict = {'colorMax': 27.4}
        bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, plotDict=plotDict))
    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=outDir, resultsDb=resultsDb)
    bg.runAll()

    bg.plotAll(closefigs=False)
# Out:
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Querying database SummaryAllProps with constraint filter="r" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 475946 visits
# Running:  ['opsim_CoaddM5_r_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 19552 visits
# Running:  ['opsim_gs_coaddM5_y_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/metricBundles/metricBundleGroup.py:495: RuntimeWarning: invalid value encountered in equal
#   b.metricValues.mask = np.where(b.metricValues.data == b.metric.badval,
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 141375 visits
# Running:  ['opsim_CoaddM5_u_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 44241 visits
# Running:  ['opsim_gs_coaddM5_i_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 208031 visits
# Running:  ['opsim_CoaddM5_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="g" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 1614 visits
# Running:  ['opsim_gs_coaddM5_g_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="r" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 17579 visits
# Running:  ['opsim_gs_coaddM5_r_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 448610 visits
# Running:  ['opsim_CoaddM5_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="i" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 481975 visits
# Running:  ['opsim_CoaddM5_i_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="u" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 469 visits
# Running:  ['opsim_gs_coaddM5_u_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="y" for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 424109 visits
# Running:  ['opsim_CoaddM5_y_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter="z" and seeingFwhmEff <= 0.7 and sunAlt < -18 for columns ['fieldRA', 'fiveSigmaDepth', 'fieldDec']
# Found 38983 visits
# Running:  ['opsim_gs_coaddM5_z_and_seeingFwhmEff_lt_0_7_and_sunAlt_lt_-18_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "filter="r"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 238 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 26.4997  dipole: lon: 116.581, lat: -70.4955, amp: 0.425264
# Plotting complete.
# Plotting figures with "filter="y" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# monopole: 23.2786  dipole: lon: 120.764, lat: -30.948, amp: 0.503914
# Plotting complete.
# Plotting figures with "filter="u"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 535 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 25.6443  dipole: lon: 104.06, lat: -25.8949, amp: 0.207339
# Plotting complete.
# Plotting figures with "filter="i" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# monopole: 25.1269  dipole: lon: 140.085, lat: -48.7313, amp: 0.372182
# Plotting complete.
# Plotting figures with "filter="g"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 239 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# monopole: 26.4886  dipole: lon: 126.712, lat: -77.8938, amp: 0.517993
# Plotting complete.
# Plotting figures with "filter="g" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# monopole: 25.141  dipole: lon: 90.1163, lat: -43.0811, amp: 0.159177
# Plotting complete.
# Plotting figures with "filter="r" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 25.2681  dipole: lon: 133.274, lat: -57.1101, amp: 0.40371
# Plotting complete.
# Plotting figures with "filter="z"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 249 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 25.279  dipole: lon: 125.794, lat: -72.4154, amp: 0.43104
# Plotting complete.
# Plotting figures with "filter="i"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 242 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 26.0065  dipole: lon: 124.472, lat: -70.5776, amp: 0.391172
# Plotting complete.
# Plotting figures with "filter="u" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 24.2868  dipole: lon: 32.8501, lat: -8.45618, amp: 0.0896907
# Plotting complete.
# Plotting figures with "filter="y"" constraint now.
# /Users/yoachim/git_repos/sims_maf/python/lsst/sims/maf/utils/mafUtils.py:58: UserWarning: Optimal bin calculation tried to make 561 bins, returning 200
#   warnings.warn('Optimal bin calculation tried to make %.0f bins, returning %i'%(nbins, nbinMax))
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 24.6606  dipole: lon: 111.661, lat: -0.426341, amp: 0.245686
# Plotting complete.
# Plotting figures with "filter="z" and seeingFwhmEff <= 0.7 and sunAlt < -18" constraint now.
# /Users/yoachim/lsst/python/miniconda3-4.5.12/envs/lsst-scipipe-1172c30/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# monopole: 24.3745  dipole: lon: 142.447, lat: -44.8084, amp: 0.461172
# Plotting complete.
